# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import json
import requests
from bs4 import BeautifulSoup
from time import sleep
from flask import Flask,render_template

# %% [markdown]
# **Check working directory**

# %%
# %pwd
# Out:
# '/Users/elle/GA_DSI/projects/Project_5'

# %% [markdown]
# ## Set up the Here.com API

# %% [markdown]
# **I define what I want the Here.com API to and get:**
# - I set up the URL with the proper path to retrieve incidents as well as the latitude and longitude of Los Angeles and the distance out from that coordinate I want to get incidents in meters.
# - I set up requests to use GET from the URL and use BeautifulSoup to pull the data from the XML

# %%
# Proximity	{base-url}/{path}/{resource}.{format}?prox={proximity coordinates}
url = "https://traffic.ls.hereapi.com/traffic/6.2/incidents.json?prox=34.05361,-118.2455,50000&apiKey=ImpjzwMBg68fDXVm4yRQJrv8K83RdONfuT9tKU3Rj20"
res = requests.get(url)
soup = BeautifulSoup(res.content, 'lxml')
soup
# Out:
# <html><body><p>{"TIMESTAMP":"02/21/2020 21:34:56 GMT","VERSION":2.3,"TRAFFIC_ITEMS":{"TRAFFIC_ITEM":[{"TRAFFIC_ITEM_ID":1467688938403884516,"ORIGINAL_TRAFFIC_ITEM_ID":1467688938403884516,"TRAFFIC_ITEM_STATUS_SHORT_DESC":"ACTIVE","TRAFFIC_ITEM_TYPE_DESC":"CONSTRUCTION","START_TIME":"02/21/2020 15:01:00","END_TIME":"02/22/2020 00:01:00","ENTRY_TIME":"02/21/2020 15:12:48","CRITICALITY":{"ID":"2","DESCRIPTION":"minor"},"VERIFIED":true,"ABBREVIATION":{"SHORT_DESC":"CONST","DESCRIPTION":"construction"},"RDS-TMC_LOCATIONS":{"RDS-TMC":[{"ORIGIN":{"EBU_COUNTRY_CODE":"1","TABLE_ID":6,"LOCATION_ID":"06065","LOCATION_DESC":"Trancas Canyon Rd","RDS_DIRECTION":"+"},"DIRECTION":"-","ALERTC":{"TRAFFIC_CODE":52,"QUANTIFIERS":0,"DESCRIPTION":"Roadwork on the hard shoulder.","ALERTC_DURATION":"L","ALERTC_DIRECTION":1,"UPDATE_CLASS":11,"PHRASE_CODE":"E11.Z146","EXTENT":"1","DURATION":0},"LENGTH":2.53938,"PRIMARY_OFFSET":1.96097},{"ORIGIN":{"EBU_COUNTRY_CODE":"1","TABLE_ID":6,"LOCATION_ID":"06065","LOCATION_DESC":"Trancas Canyon Rd","RDS_DIRECTION":"+"},"DIRECTION":"-","ALERTC":{"TRAFFIC_CODE":500,"QUANTIFIERS":0,"DESCRIPTION":"Lane closed.","ALERTC_DURATION":"L","ALERTC_DIRECTION":1,"UPDATE_CLASS":5,"PHRASE_CODE":"D1","EXTENT":"1","DURATION":0},"LENGTH":2.53938,"PRIMARY_OFFSET":1.96097}]},"LOCATION":{"DEFINED":{"ORIGIN":{"ROADWAY":{"DESCRIPTION":[{"value":"SR-1","TYPE":"NTCSA"},{"value":"SR-1","TYPE":"RDSGN"},{"value":"SR-1","TYPE":"LOCAL"}],"ID":153},"POINT":{"DESCRIPTION":[{"value":"Encinal Canyon Rd","TYPE":"NTCSA"},{"value":"Encinal Canyon Rd","TYPE":"RDSGN"},{"value":"Encinal Canyon Rd","TYPE":"LOCAL"},{"value":"SR-1","TYPE":"BNAME"}],"ID":6065},"DIRECTION":{"DESCRIPTION":[{"value":"SOUTHBOUND","TYPE":"LOCAL"},{"value":"SOUTHBOUND","TYPE":"NTCSA"},{"value":"SOUTHBOUND","TYPE":"RDSGN"}],"ID":0},"PROXIMITY":{"ID":"AT","DESCRIPTION":"at"}},"TO":{"ROADWAY":{"DESCRIPTION":[{"value":"SR-1","TYPE":"NTCSA"},{"value":"SR-1","TYPE":"RDSGN"},{"value":"SR-1","TYPE":"LOCAL"}],"ID":153},"POINT":{"DESCRIPTION":[{"value":"Trancas Canyon Rd","TYPE":"NTCSA"},{"value":"Trancas Canyon Rd","TYPE":"RDSGN"},{"value":"Trancas Canyon Rd","TYPE":"LOCAL"},{"value":"SR-1","TYPE":"BNAME"}],"ID":6065},"DIRECTION":{"DESCRIPTION":[{"value":"SOUTHBOUND","TYPE":"LOCAL"},{"value":"SOUTHBOUND","TYPE":"NTCSA"},{"value":"SOUTHBOUND","TYPE":"RDSGN"}],"ID":0},"PROXIMITY":{"ID":"AT","DESCRIPTION":"at"}}},"GEOLOC":{"ORIGIN":{"LATITUDE":34.04039,"LONGITUDE":-118.88558},"TO":[{"LATITUDE":34.03112,"LONGITUDE":-118.84363}]},"NAVTECH":{"EDGE":{"EDGE_ID":["1146410624","1146410622","1146410621","910656992","810546880","814203412","814203411","1146410627","1146410626","1146412084","1146412083","24588570","1146413541","1146413540","128792729","1146414243","1252992542","1252992547","1252992546"]},"VERSION_ID":"202001"},"LENGTH":2.53938},"TRAFFIC_ITEM_DETAIL":{"ROAD_CLOSED":false,"EVENT":{"EVENT_ITEM_CANCELLED":false,"SCHEDULED_CONSTRUCTION_EVENT":{"SCHEDULED_CONSTRUCTION_TYPE_DESC":"CONSTRUCTION","SCHEDULED_CONSTRUCTION_DETAIL":"construction"}},"ALERTC":[{"EVENT_CODE":52},{"EVENT_CODE":500}]},"TRAFFIC_ITEM_DESCRIPTION":[{"value":"At Trancas Canyon Rd - Roadwork on the hard shoulder. Lane closed.","TYPE":"short_desc"},{"value":"At Trancas Canyon Rd - Roadwork on the hard shoulder. Lane closed.","TYPE":"desc"},{"value":"Roadwork on the hard shoulder. Lane closed.","TYPE":"no_exit_description"}],"mid":"C1TB-0005-2020-02-21-07:01:00|1582297928447","PRODUCT":"basic"},{"TRAFFIC_ITEM_ID":4039834515858037750,"ORIGINAL_TRAFFIC_ITEM_ID":4533751053977392789,"TRAFFIC_ITEM_STATUS_SHORT_DESC":"ACTIVE","TRAFFIC_ITEM_TYPE_DESC":"CONSTRUCTION","START_TIME":"02/21/2020 20:33:54","END_TIME":"02/25/2020 20:31:48","ENTRY_TIME":"02/21/2020 20:33:54","CRITICALITY":{"ID":"1","DESCRIPTION":"major"},"VERIFIED":true,"ABBREVIATION":{"SHORT_DESC":"CONST","DESCRIPTION":"construction"},"RDS-TMC_LOCATIONS":{"RDS-TMC":[{"ORIGIN":{"EBU_COUNTRY_CODE":"1","TABLE_ID":6,"LOCATION_ID":"17237","LOCATION_DESC":"3rd St","RDS_DIRECTIO ...

# %% [markdown]
# ## Create a dictionary of the data

# %%
inc_dict = res.json()['TRAFFIC_ITEMS']['TRAFFIC_ITEM']
inc_dict
# Out:
# [{'TRAFFIC_ITEM_ID': 1467688938403884516,
#   'ORIGINAL_TRAFFIC_ITEM_ID': 1467688938403884516,
#   'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#   'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#   'START_TIME': '02/21/2020 15:01:00',
#   'END_TIME': '02/22/2020 00:01:00',
#   'ENTRY_TIME': '02/21/2020 15:12:48',
#   'CRITICALITY': {'ID': '2', 'DESCRIPTION': 'minor'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'RDS-TMC_LOCATIONS': {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '06065',
#       'LOCATION_DESC': 'Trancas Canyon Rd',
#       'RDS_DIRECTION': '+'},
#      'DIRECTION': '-',
#      'ALERTC': {'TRAFFIC_CODE': 52,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Roadwork on the hard shoulder.',
#       'ALERTC_DURATION': 'L',
#       'ALERTC_DIRECTION': 1,
#       'UPDATE_CLASS': 11,
#       'PHRASE_CODE': 'E11.Z146',
#       'EXTENT': '1',
#       'DURATION': 0},
#      'LENGTH': 2.53938,
#      'PRIMARY_OFFSET': 1.96097},
#     {'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '06065',
#       'LOCATION_DESC': 'Trancas Canyon Rd',
#       'RDS_DIRECTION': '+'},
#      'DIRECTION': '-',
#      'ALERTC': {'TRAFFIC_CODE': 500,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Lane closed.',
#       'ALERTC_DURATION': 'L',
#       'ALERTC_DIRECTION': 1,
#       'UPDATE_CLASS': 5,
#       'PHRASE_CODE': 'D1',
#       'EXTENT': '1',
#       'DURATION': 0},
#      'LENGTH': 2.53938,
#      'PRIMARY_OFFSET': 1.96097}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'value': 'SR-1',
#         'TYPE': 'NTCSA'},
#        {'value': 'SR-1', 'TYPE': 'RDSGN'},
#        {'value': 'SR-1', 'TYPE': 'LOCAL'}],
#       'ID': 153},
#      'POINT': {'DESCRIPTION': [{'value': 'Encinal Canyon Rd', 'TYPE': 'NTCSA'},
#        {'value': 'Encinal Canyon Rd', 'TYPE': 'RDSGN'},
#        {'value': 'Encinal Canyon Rd', 'TYPE': 'LOCAL'},
#        {'value': 'SR-1', 'TYPE': 'BNAME'}],
#       'ID': 6065},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'SOUTHBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'SOUTHBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'SOUTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'value': 'SR-1', 'TYPE': 'NTCSA'},
#        {'value': 'SR-1', 'TYPE': 'RDSGN'},
#        {'value': 'SR-1', 'TYPE': 'LOCAL'}],
#       'ID': 153},
#      'POINT': {'DESCRIPTION': [{'value': 'Trancas Canyon Rd', 'TYPE': 'NTCSA'},
#        {'value': 'Trancas Canyon Rd', 'TYPE': 'RDSGN'},
#        {'value': 'Trancas Canyon Rd', 'TYPE': 'LOCAL'},
#        {'value': 'SR-1', 'TYPE': 'BNAME'}],
#       'ID': 6065},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'SOUTHBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'SOUTHBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'SOUTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.04039, 'LONGITUDE': -118.88558},
#     'TO': [{'LATITUDE': 34.03112, 'LONGITUDE': -118.84363}]},
#    'NAVTECH': {'EDGE': {'EDGE_ID': ['1146410624',
#       '1146410622',
#       '1146410621',
#       '910656992',
#       '810546880',
#       '814203412',
#       '814203411',
#       '1146410627',
#       '1146410626',
#       '1146412084',
#       '1146412083',
#       '24588570',
#       '1146413541',
#       '1146413540',
#       '128792729',
#       '1146414243',
#       '1252992542',
#       '1252992547',
#       '1252992546']},
#     'VERSION_ID': '202001'},
#    'LENGTH': 2.53938},
#   'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': False,
#    'EVENT': {'EVENT_ITEM_CANCELLED': False,
#     'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#      'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#    'ALERTC': [{'EVENT_CODE': 52}, {'EVENT_CODE': 500}]},
#   'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'At Trancas Canyon Rd - Roadwork on the hard shoulder. Lane closed.',
#     'TYPE': 'short_desc'},
#    {'value': 'At Trancas Canyon Rd - Roadwork on the hard shoulder. Lane closed.',
#     'TYPE': 'desc'},
#    {'value': 'Roadwork on the hard shoulder. Lane closed.',
#     'TYPE': 'no_exit_description'}],
#   'mid': 'C1TB-0005-2020-02-21-07:01:00|1582297928447',
#   'PRODUCT': 'basic'},
#  {'TRAFFIC_ITEM_ID': 4039834515858037750,
#   'ORIGINAL_TRAFFIC_ITEM_ID': 4533751053977392789,
#   'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#   'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#   'START_TIME': '02/21/2020 20:33:54',
#   'END_TIME': '02/25/2020 20:31:48',
#   'ENTRY_TIME': '02/21/2020 20:33:54',
#   'CRITICALITY': {'ID': '1', 'DESCRIPTION': 'major'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'RDS-TMC_LOCATIONS': {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '17237',
#       'LOCATION_DESC': '3rd St',
#       'RDS_DIRECTION': '-'},
#      'TO': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '17239',
#       'LOCATION_DESC': 'N Alameda St/Alhambra Ave/Ord St',
#       'RDS_DIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFIC_CODE': 701,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Roadwork.',
#       'ALERTC_DURATION': 'L',
#       'ALERTC_DIRECTION': 1,
#       'UPDATE_CLASS': 11,
#       'PHRASE_CODE': 'E1',
#       'EXTENT': '3',
#       'DURATION': 0},
#      'LENGTH': 0.73867,
#      'PRIMARY_OFFSET': 0.0}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'value': 'Main St',
#         'TYPE': 'NTCSA'},
#        {'value': 'Main St', 'TYPE': 'RDSGN'},
#        {'value': 'Main St', 'TYPE': 'LOCAL'}],
#       'ID': 2031},
#      'POINT': {'DESCRIPTION': [{'value': '3rd St', 'TYPE': 'NTCSA'},
#        {'value': '3rd St', 'TYPE': 'RDSGN'},
#        {'value': '3rd St', 'TYPE': 'LOCAL'},
#        {'value': 'Main St', 'TYPE': 'BNAME'}],
#       'ID': 17237},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'NORTHBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'NORTHBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'NORTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'value': 'N Main St', 'TYPE': 'NTCSA'},
#        {'value': 'N Main St', 'TYPE': 'RDSGN'},
#        {'value': 'N Main St', 'TYPE': 'LOCAL'}],
#       'ID': 2031},
#      'POINT': {'DESCRIPTION': [{'value': 'N Alameda St/Alhambra Ave/Ord St',
#         'TYPE': 'NTCSA'},
#        {'value': 'N Alameda St/Alhambra Ave/Ord St', 'TYPE': 'RDSGN'},
#        {'value': 'N Alameda St/Alhambra Ave/Ord St', 'TYPE': 'LOCAL'},
#        {'value': 'N Main St', 'TYPE': 'BNAME'}],
#       'ID': 17239},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'NORTHBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'NORTHBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'NORTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.05102, 'LONGITUDE': -118.24453},
#     'TO': [{'LATITUDE': 34.05944, 'LONGITUDE': -118.2368}]},
#    'NAVTECH': {'EDGE': {'EDGE_ID': ['1152678298',
#       '1152733280',
#       '1152733281',
#       '128816424',
#       '1130008644',
#       '1130008645',
#       '960416234',
#       '960416235',
#       '939320283',
#       '960416231',
#       '960416232',
#       '764954837',
#       '1189958355',
#       '1189958356',
#       '1060361092',
#       '1060361093',
#       '1060361094',
#       '1060361095',
#       '1237115947',
#       '1237115948',
#       '37847009',
#       '1179519975',
#       '1179519976',
#       '724570165',
#       '783631597',
#       '1253486037',
#       '1253486038',
#       '783631596',
#       '783575194',
#       '783575195',
#       '939441642',
#       '939441643',
#       '783568193']},
#     'VERSION_ID': '202001'},
#    'LENGTH': 0.73867},
#   'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': False,
#    'EVENT': {'EVENT_ITEM_CANCELLED': False,
#     'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#      'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#    'ALERTC': [{'EVENT_CODE': 701}]},
#   'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Between 3rd St and N Alameda St/Alhambra Ave/Ord St - Roadwork.',
#     'TYPE': 'short_desc'},
#    {'value': 'Between 3rd St and N Alameda St/Alhambra Ave/Ord St - Roadwork.',
#     'TYPE': 'desc'},
#    {'value': 'Roadwork.', 'TYPE': 'no_exit_description'}],
#   'mid': '8e309e7a-d033-4ccf-afa9-30303d95bd21|1582317234857',
#   'PRODUCT': 'basic'},
#  {'TRAFFIC_ITEM_ID': 4631132704013455242,
#   'ORIGINAL_TRAFFIC_ITEM_ID': 348152111757174866,
#   'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#   'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#   'START_TIME': '02/21/2020 20:33:54',
#   'END_TIME': '02/25/2020 20:31:48',
#   'ENTRY_TIME': '02/21/2020 20:33:54',
#   'CRITICALITY': {'ID': '2', 'DESCRIPTION': 'minor'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'RDS-TMC_LOCATIONS': {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '09895',
#       'LOCATION_DESC': 'Veteran Ave',
#       'RDS_DIRECTION': '-'},
#      'TO': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '09897',
#       'LOCATION_DESC': 'Westholme Ave',
#       'RDS_DIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFIC_CODE': 803,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Construction work.',
#       'ALERTC_DURATION': 'L',
#       'ALERTC_DIRECTION': 1,
#       'UPDATE_CLASS': 11,
#       'PHRASE_CODE': 'E11',
#       'EXTENT': '3',
#       'DURATION': 0},
#      'LENGTH': 0.8483,
#      'PRIMARY_OFFSET': 0.47828}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'value': 'Wilshire Blvd',
#         'TYPE': 'NTCSA'},
#        {'value': 'Wilshire Blvd', 'TYPE': 'RDSGN'},
#        {'value': 'Wilshire Blvd', 'TYPE': 'LOCAL'}],
#       'ID': 760},
#      'POINT': {'DESCRIPTION': [{'value': 'Veteran Ave', 'TYPE': 'NTCSA'},
#        {'value': 'Veteran Ave', 'TYPE': 'RDSGN'},
#        {'value': 'Veteran Ave', 'TYPE': 'LOCAL'},
#        {'value': 'Wilshire Blvd', 'TYPE': 'BNAME'}],
#       'ID': 9895},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'EASTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'EASTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'EASTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'value': 'Wilshire Blvd',
#         'TYPE': 'NTCSA'},
#        {'value': 'Wilshire Blvd', 'TYPE': 'RDSGN'},
#        {'value': 'Wilshire Blvd', 'TYPE': 'LOCAL'}],
#       'ID': 760},
#      'POINT': {'DESCRIPTION': [{'value': 'Westholme Ave', 'TYPE': 'NTCSA'},
#        {'value': 'Westholme Ave', 'TYPE': 'RDSGN'},
#        {'value': 'Westholme Ave', 'TYPE': 'LOCAL'},
#        {'value': 'Wilshire Blvd', 'TYPE': 'BNAME'}],
#       'ID': 9897},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'EASTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'EASTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'EASTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.05776, 'LONGITUDE': -118.44775},
#     'TO': [{'LATITUDE': 34.06151, 'LONGITUDE': -118.43369}]},
#    'NAVTECH': {'EDGE': {'EDGE_ID': ['764603554',
#       '764603555',
#       '764603556',
#       '764603566',
#       '764603567',
#       '1154984806',
#       '1154984807',
#       '764603557',
#       '764603558',
#       '764603559',
#       '1238097147',
#       '1238097148',
#       '1151919181',
#       '1238097139',
#       '1238097140',
#       '1151401017',
#       '1151401018',
#       '1151420458',
#       '1151420459',
#       '1151401020',
#       '1151401021',
#       '1151420456',
#       '1151420457',
#       '1151401911',
#       '1151401912',
#       '1151401913',
#       '1151401914']},
#     'VERSION_ID': '202001'},
#    'LENGTH': 0.8483},
#   'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': False,
#    'EVENT': {'EVENT_ITEM_CANCELLED': False,
#     'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#      'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#    'ALERTC': [{'EVENT_CODE': 803}]},
#   'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Between Veteran Ave and Westholme Ave - Construction work.',
#     'TYPE': 'short_desc'},
#    {'value': 'Between Veteran Ave and Westholme Ave - Construction work.',
#     'TYPE': 'desc'},
#    {'value': 'Construction work.', 'TYPE': 'no_exit_description'}],
#   'mid': 'NAVTEQ/r_NAVTEQ/10259131_original|1582317199029',
#   'PRODUCT': 'basic'},
#  {'TRAFFIC_ITEM_ID': 1767679166603155458,
#   'ORIGINAL_TRAFFIC_ITEM_ID': 416214841872537122,
#   'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#   'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#   'START_TIME': '02/21/2020 20:33:54',
#   'END_TIME': '02/25/2020 20:31:48',
#   'ENTRY_TIME': '02/21/2020 20:33:54',
#   'CRITICALITY': {'ID': '2', 'DESCRIPTION': 'minor'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'COMMENTS': '- expect intermittent lane closure at various intervals for bridge replacement',
#   'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#      'STREET1': {'ADDRESS1': 'Ravenna Dr'},
#      'STREET2': {'ADDRESS1': '2nd St'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}},
#     'TO': {'ID': '',
#      'STREET1': {'ADDRESS1': 'Ravenna Dr'},
#      'STREET2': {'ADDRESS1': 'Naples Ln'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 33.75693, 'LONGITUDE': -118.12304},
#     'TO': [{'LATITUDE': 33.75516, 'LONGITUDE': -118.12345}],
#     'GEOMETRY': {'SHAPES': {'SHP': [{'value': '33.75693,-118.12304 33.75683,-118.12303',
#         'FC': 5,
#         'LID': '121238382T',
#         'LE': 0.011130254108919983,
#         'FW': 'SD'},
#        {'value': '33.75683,-118.12303 33.75651,-118.12312',
#         'FC': 5,
#         'LID': '1195443886T',
#         'LE': 0.03646014574122676,
#         'FW': 'SD'},
#        {'value': '33.75651,-118.12312 33.75622,-118.12319',
#         'FC': 5,
#         'LID': '1195443885T',
#         'LE': 0.03281353977711482,
#         'FW': 'SD'},
#        {'value': '33.75622,-118.12319 33.75592,-118.12325',
#         'FC': 5,
#         'LID': '23891289T',
#         'LE': 0.03373658781212216,
#         'FW': 'SD'},
#        {'value': '33.75592,-118.12325 33.75562,-118.12333',
#         'FC': 5,
#         'LID': '841593802T',
#         'LE': 0.034090833651660095,
#         'FW': 'SD'},
#        {'value': '33.75562,-118.12333 33.75558,-118.12334',
#         'FC': 5,
#         'LID': '841593801T',
#         'LE': 0.004532054365363909,
#         'FW': 'SD'},
#        {'value': '33.75558,-118.12334 33.75551,-118.12336 33.75546,-118.12338',
#         'FC': 5,
#         'LID': '841593804T',
#         'LE': 0.013828283902712481,
#         'FW': 'SD'},
#        {'value': '33.75546,-118.12338 33.75538,-118.1234',
#         'FC': 5,
#         'LID': '841593803T',
#         'LE': 0.009065100726407656,
#         'FW': 'SD'},
#        {'value': '33.75538,-118.1234 33.75516,-118.12345',
#         'FC': 5,
#         'LID': '23891641T',
#         'LE': 0.024837891388144816,
#         'FW': 'SD'}]}}},
#    'POLITICAL_BOUNDARY': {'METRO_AREA': {'value': '', 'ID': 6},
#     'COUNTY': 'Los Angeles',
#     'MUNICIPALITY': {'NAME': 'Long Beach'}},
#    'NAVTECH': {'EDGE': {'EDGE_ID': ['121238382',
#       '1195443886',
#       '1195443885',
#       '23891289',
#       '841593802',
#       '841593801',
#       '841593804',
#       '841593803',
#       '23891641']},
#     'VERSION_ID': '202001'},
#    'LENGTH': 0.12457},
#   'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': False,
#    'EVENT': {'EVENT_ITEM_CANCELLED': False,
#     'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#      'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#    'ALERTC': [{'EVENT_CODE': 701}]},
#   'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Between 2nd St and Naples Ln - Roadwork.',
#     'TYPE': 'short_desc'},
#    {'value': 'Between 2nd St and Naples Ln - Roadwork. - expect intermittent lane closure at various intervals for bridge replacement',
#     'TYPE': 'desc'},
#    {'value': 'Roadwork. - expect intermittent lane closure at various intervals for bridge replacement',
#     'TYPE': 'no_exit_description'}],
#   'mid': 'HERE-Non-Europe-PR/r_HERE-Non-Europe-PR/648376_TIC/NAVTEQ_original|1582317199030',
#   'PRODUCT': 'basic'},
#  {'TRAFFIC_ITEM_ID': 950684747963159237,
#   'ORIGINAL_TRAFFIC_ITEM_ID': 1753243970756066759,
#   'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#   'TRAFFIC_ITEM_TYPE_DESC': 'CONGESTION',
#   'START_TIME': '02/21/2020 21:31:46',
#   'END_TIME': '02/21/2020 21:46:46',
#   'ENTRY_TIME': '02/21/2020 21:33:55',
#   'CRITICALITY': {'ID': '2', 'DESCRIPTION': 'minor'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORT_DESC': 'SLOW', 'DESCRIPTION': 'slow'},
#   'RDS-TMC_LOCATIONS': {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '04812',
#       'LOCATION_DESC': 'Lorena St',
#       'RDS_DIRECTION': '-'},
#      'TO': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '04813',
#       'LOCATION_DESC': 'I-5',
#       'RDS_DIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFIC_CODE': 136,
#       'QUANTIFIERS': 4,
#       'DESCRIPTION': 'Traffic congestion.',
#       'ALERTC_DURATION': 'D',
#       'ALERTC_DIRECTION': 1,
#       'UPDATE_CLASS': 1,
#       'PHRASE_CODE': 'A9',
#       'EXTENT': '2',
#       'DURATION': 0,
#       'SUPP_TRAFFIC_CODE': [{'CODE': 141}]},
#      'LENGTH': 0.4578,
#      'PRIMARY_OFFSET': 0.43446}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'value': 'CA-60',
#         'TYPE': 'NTCSA'},
#        {'value': 'CA-60', 'TYPE': 'RDSGN'},
#        {'value': 'CA-60', 'TYPE': 'LOCAL'}],
#       'ID': 80},
#      'POINT': {'DESCRIPTION': [{'value': 'Lorena St', 'TYPE': 'NTCSA'},
#        {'value': 'Lorena St', 'TYPE': 'RDSGN'},
#        {'value': 'Lorena St', 'TYPE': 'LOCAL'},
#        {'value': 'CA-60', 'TYPE': 'BNAME'}],
#       'ID': 4812},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'WESTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'WESTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'WESTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'value': 'CA-60', 'TYPE': 'NTCSA'},
#        {'value': 'CA-60', 'TYPE': 'RDSGN'},
#        {'value': 'CA-60', 'TYPE': 'LOCAL'}],
#       'ID': 80},
#      'POINT': {'DESCRIPTION': [{'value': 'I-5', 'TYPE': 'NTCSA'},
#        {'value': 'I-5', 'TYPE': 'RDSGN'},
#        {'value': 'I-5', 'TYPE': 'LOCAL'},
#        {'value': 'CA-60', 'TYPE': 'BNAME'}],
#       'ID': 4813},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'WESTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'WESTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'WESTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.02935, 'LONGITUDE': -118.20087},
#     'TO': [{'LATITUDE': 34.02847, 'LONGITUDE': -118.20875}]},
#    'NAVTECH': {'EDGE': {'EDGE_ID': ['1183421426',
#       '1183421425',
#       '128809616',
#       '128809615',
#       '782857571',
#       '782857570']},
#     'VERSION_ID': '202001'},
#    'LENGTH': 0.4578},
#   'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': False,
#    'INCIDENT': {'RESPONSE_VEHICLES': False,
#     'CONGESTION_INCIDENT': {'CONGESTION_TYPE_DESC': 'CONGESTION',
#      'CONGESTION_FACTOR': 50}},
#    'ALERTC': [{'EVENT_CODE': 136, 'SUPP_TRAFFIC_CODE': [141]}]},
#   'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Between Lorena St and I-5 - Traffic congestion. on the right.',
#     'TYPE': 'short_desc'},
#    {'value': 'Between Lorena St and I-5 - Traffic congestion. on the right.',
#     'TYPE': 'desc'},
#    {'value': 'Traffic congestion. on the right.',
#     'TYPE': 'no_exit_description'}],
#   'mid': '492859251582320706161|1582320826167',
#   'PRODUCT': 'basic'},
#  {'TRAFFIC_ITEM_ID': 1006329517941158994,
#   'ORIGINAL_TRAFFIC_ITEM_ID': 4008574319594790243,
#   'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#   'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#   'START_TIME': '02/21/2020 20:33:54',
#   'END_TIME': '02/25/2020 20:31:48',
#   'ENTRY_TIME': '02/21/2020 20:33:54',
#   'CRITICALITY': {'ID': '1', 'DESCRIPTION': 'major'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'RDS-TMC_LOCATIONS': {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '17310',
#       'LOCATION_DESC': 'Broadway',
#       'RDS_DIRECTION': '+'},
#      'DIRECTION': '-',
#      'ALERTC': {'TRAFFIC_CODE': 701,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Roadwork.',
#       'ALERTC_DURATION': 'L',
#       'ALERTC_DIRECTION': 1,
#       'UPDATE_CLASS': 11,
#       'PHRASE_CODE': 'E1',
#       'EXTENT': '1',
#       'DURATION': 0},
#      'LENGTH': 0.0,
#      'PRIMARY_OFFSET': 0.23239}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'value': 'W 1st St',
#         'TYPE': 'NTCSA'},
#        {'value': 'W 1st St', 'TYPE': 'RDSGN'},
#        {'value': 'W 1st St', 'TYPE': 'LOCAL'}],
#       'ID': 2043},
#      'POINT': {'DESCRIPTION': [{'value': 'Hope St', 'TYPE': 'NTCSA'},
#        {'value': 'Hope St', 'TYPE': 'RDSGN'},
#        {'value': 'Hope St', 'TYPE': 'LOCAL'},
#        {'value': 'W 1st St', 'TYPE': 'BNAME'}],
#       'ID': 17310},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'EASTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'EASTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'EASTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'value': 'W 1st St', 'TYPE': 'NTCSA'},
#        {'value': 'W 1st St', 'TYPE': 'RDSGN'},
#        {'value': 'W 1st St', 'TYPE': 'LOCAL'}],
#       'ID': 2043},
#      'POINT': {'DESCRIPTION': [{'value': 'Broadway', 'TYPE': 'NTCSA'},
#        {'value': 'Broadway', 'TYPE': 'RDSGN'},
#        {'value': 'Broadway', 'TYPE': 'LOCAL'},
#        {'value': 'W 1st St', 'TYPE': 'BNAME'}],
#       'ID': 17310},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'EASTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'EASTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'EASTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.0557, 'LONGITUDE': -118.24878},
#     'TO': [{'LATITUDE': 34.0557, 'LONGITUDE': -118.24878}]},
#    'NAVTECH': {'EDGE': {'EDGE_ID': ['1152747478']}, 'VERSION_ID': '202001'},
#    'LENGTH': 0.0},
#   'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': False,
#    'EVENT': {'EVENT_ITEM_CANCELLED': False,
#     'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#      'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#    'ALERTC': [{'EVENT_CODE': 701}]},
#   'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'At Broadway - Roadwork.',
#     'TYPE': 'short_desc'},
#    {'value': 'At Broadway - Roadwork.', 'TYPE': 'desc'},
#    {'value': 'Roadwork.', 'TYPE': 'no_exit_description'}],
#   'mid': 'a729b304-2472-404f-a5e4-6686c40587d1|1582317234882',
#   'PRODUCT': 'basic'},
#  {'TRAFFIC_ITEM_ID': 3428335694381294226,
#   'ORIGINAL_TRAFFIC_ITEM_ID': 815068663641351778,
#   'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#   'TRAFFIC_ITEM_TYPE_DESC': 'ACCIDENT',
#   'START_TIME': '02/21/2020 13:32:00',
#   'END_TIME': '02/21/2020 22:03:48',
#   'ENTRY_TIME': '02/21/2020 21:34:39',
#   'CRITICALITY': {'ID': '2', 'DESCRIPTION': 'minor'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORT_DESC': 'ACC', 'DESCRIPTION': ''},
#   'RDS-TMC_LOCATIONS': {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '07230',
#       'LOCATION_DESC': 'S Atlantic Ave',
#       'RDS_DIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFIC_CODE': 201,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Accident.',
#       'ALERTC_DURATION': '(D)',
#       'ALERTC_DIRECTION': 1,
#       'UPDATE_CLASS': 3,
#       'PHRASE_CODE': 'B1',
#       'EXTENT': '1',
#       'DURATION': 0},
#      'LENGTH': 0.0,
#      'PRIMARY_OFFSET': 0.16783}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'value': 'Rosecrans Ave',
#         'TYPE': 'NTCSA'},
#        {'value': 'Rosecrans Ave', 'TYPE': 'RDSGN'},
#        {'value': 'Rosecrans Ave', 'TYPE': 'LOCAL'}],
#       'ID': 492},
#      'POINT': {'DESCRIPTION': [{'value': 'N Long Beach Blvd', 'TYPE': 'NTCSA'},
#        {'value': 'N Long Beach Blvd', 'TYPE': 'RDSGN'},
#        {'value': 'N Long Beach Blvd', 'TYPE': 'LOCAL'},
#        {'value': 'Rosecrans Ave', 'TYPE': 'BNAME'}],
#       'ID': 7230},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'EASTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'EASTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'EASTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'value': 'Rosecrans Ave',
#         'TYPE': 'NTCSA'},
#        {'value': 'Rosecrans Ave', 'TYPE': 'RDSGN'},
#        {'value': 'Rosecrans Ave', 'TYPE': 'LOCAL'}],
#       'ID': 492},
#      'POINT': {'DESCRIPTION': [{'value': 'S Atlantic Ave', 'TYPE': 'NTCSA'},
#        {'value': 'S Atlantic Ave', 'TYPE': 'RDSGN'},
#        {'value': 'S Atlantic Ave', 'TYPE': 'LOCAL'},
#        {'value': 'Rosecrans Ave', 'TYPE': 'BNAME'}],
#       'ID': 7230},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'EASTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'EASTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'EASTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 33.903541, 'LONGITUDE': -118.196861},
#     'TO': [{'LATITUDE': 33.903541, 'LONGITUDE': -118.196861}]},
#    'NAVTECH': {'EDGE': {'EDGE_ID': ['1252439643']}, 'VERSION_ID': '202001'},
#    'LENGTH': 0.0},
#   'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': False,
#    'INCIDENT': {'RESPONSE_VEHICLES': False, 'ACCIDENT_INCIDENT': {}},
#    'ALERTC': [{'EVENT_CODE': 201}]},
#   'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'At S Atlantic Ave - Accident.',
#     'TYPE': 'short_desc'},
#    {'value': 'At S Atlantic Ave - Accident.', 'TYPE': 'desc'},
#    {'value': 'Accident.', 'TYPE': 'no_exit_description'}],
#   'mid': '200221LA00399|1582320857389',
#   'PRODUCT': 'basic'},
#  {'TRAFFIC_ITEM_ID': 1165370087655826994,
#   'ORIGINAL_TRAFFIC_ITEM_ID': 1165370087655826994,
#   'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#   'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#   'START_TIME': '02/21/2020 16:31:35',
#   'END_TIME': '02/25/2020 16:30:59',
#   'ENTRY_TIME': '02/21/2020 16:31:35',
#   'CRITICALITY': {'ID': '2', 'DESCRIPTION': 'minor'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'RDS-TMC_LOCATIONS': {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '07066',
#       'LOCATION_DESC': 'Pioneer Blvd',
#       'RDS_DIRECTION': '+'},
#      'DIRECTION': '-',
#      'ALERTC': {'TRAFFIC_CODE': 803,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Construction work.',
#       'ALERTC_DURATION': 'L',
#       'ALERTC_DIRECTION': 1,
#       'UPDATE_CLASS': 11,
#       'PHRASE_CODE': 'E11',
#       'EXTENT': '1',
#       'DURATION': 0},
#      'LENGTH': 0.08097,
#      'PRIMARY_OFFSET': 0.06577}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'value': 'Firestone Blvd',
#         'TYPE': 'NTCSA'},
#        {'value': 'Firestone Blvd', 'TYPE': 'RDSGN'},
#        {'value': 'Firestone Blvd', 'TYPE': 'LOCAL'}],
#       'ID': 417},
#      'POINT': {'DESCRIPTION': [{'value': 'Paddison Ave', 'TYPE': 'NTCSA'},
#        {'value': 'Paddison Ave', 'TYPE': 'RDSGN'},
#        {'value': 'Paddison Ave', 'TYPE': 'LOCAL'},
#        {'value': 'Firestone Blvd', 'TYPE': 'BNAME'}],
#       'ID': 7066},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'WESTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'WESTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'WESTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'value': 'Firestone Blvd',
#         'TYPE': 'NTCSA'},
#        {'value': 'Firestone Blvd', 'TYPE': 'RDSGN'},
#        {'value': 'Firestone Blvd', 'TYPE': 'LOCAL'}],
#       'ID': 417},
#      'POINT': {'DESCRIPTION': [{'value': 'Pioneer Blvd', 'TYPE': 'NTCSA'},
#        {'value': 'Pioneer Blvd', 'TYPE': 'RDSGN'},
#        {'value': 'Pioneer Blvd', 'TYPE': 'LOCAL'},
#        {'value': 'Firestone Blvd', 'TYPE': 'BNAME'}],
#       'ID': 7066},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'WESTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'WESTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'WESTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 33.91166, 'LONGITUDE': -118.07973},
#     'TO': [{'LATITUDE': 33.9123, 'LONGITUDE': -118.08091}]},
#    'NAVTECH': {'EDGE': {'EDGE_ID': ['1252841822', '1236710209', '1236710210']},
#     'VERSION_ID': '202001'},
#    'LENGTH': 0.08097},
#   'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': False,
#    'EVENT': {'EVENT_ITEM_CANCELLED': False,
#     'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#      'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#    'ALERTC': [{'EVENT_CODE': 803}]},
#   'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'At Pioneer Blvd - Construction work.',
#     'TYPE': 'short_desc'},
#    {'value': 'At Pioneer Blvd - Construction work.', 'TYPE': 'desc'},
#    {'value': 'Construction work.', 'TYPE': 'no_exit_description'}],
#   'mid': 'HERE-Non-Europe-PR/r_HERE-Non-Europe-PR/730563_TIC/NAVTEQ_original|1582302659683',
#   'PRODUCT': 'basic'},
#  {'TRAFFIC_ITEM_ID': 267043895435086839,
#   'ORIGINAL_TRAFFIC_ITEM_ID': 2766454847170085390,
#   'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#   'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#   'START_TIME': '02/21/2020 20:33:54',
#   'END_TIME': '02/25/2020 20:31:48',
#   'ENTRY_TIME': '02/21/2020 20:33:54',
#   'CRITICALITY': {'ID': '1', 'DESCRIPTION': 'major'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'COMMENTS': '- expect intermittent lane closures at various intervals',
#   'RDS-TMC_LOCATIONS': {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '17309',
#       'LOCATION_DESC': 'Central Ave',
#       'RDS_DIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFIC_CODE': 701,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Roadwork.',
#       'ALERTC_DURATION': 'L',
#       'ALERTC_DIRECTION': 1,
#       'UPDATE_CLASS': 11,
#       'PHRASE_CODE': 'E1',
#       'EXTENT': '1',
#       'DURATION': 0},
#      'LENGTH': 0.06047,
#      'PRIMARY_OFFSET': 0.32096}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'value': '1st St',
#         'TYPE': 'NTCSA'},
#        {'value': '1st St', 'TYPE': 'RDSGN'},
#        {'value': '1st St', 'TYPE': 'LOCAL'}],
#       'ID': 2043},
#      'POINT': {'DESCRIPTION': [{'value': 'Alameda St', 'TYPE': 'NTCSA'},
#        {'value': 'Alameda St', 'TYPE': 'RDSGN'},
#        {'value': 'Alameda St', 'TYPE': 'LOCAL'},
#        {'value': '1st St', 'TYPE': 'BNAME'}],
#       'ID': 17309},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'WESTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'WESTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'WESTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'value': '1st St', 'TYPE': 'NTCSA'},
#        {'value': '1st St', 'TYPE': 'RDSGN'},
#        {'value': '1st St', 'TYPE': 'LOCAL'}],
#       'ID': 2043},
#      'POINT': {'DESCRIPTION': [{'value': 'Central Ave', 'TYPE': 'NTCSA'},
#        {'value': 'Central Ave', 'TYPE': 'RDSGN'},
#        {'value': 'Central Ave', 'TYPE': 'LOCAL'},
#        {'value': '1st St', 'TYPE': 'BNAME'}],
#       'ID': 17309},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'WESTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'WESTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'WESTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.04899, 'LONGITUDE': -118.23813},
#     'TO': [{'LATITUDE': 34.04921, 'LONGITUDE': -118.23915}]},
#    'NAVTECH': {'EDGE': {'EDGE_ID': ['1236786454', '1236786455', '1152738045']},
#     'VERSION_ID': '202001'},
#    'LENGTH': 0.06047},
#   'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': False,
#    'EVENT': {'EVENT_ITEM_CANCELLED': False,
#     'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#      'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#    'ALERTC': [{'EVENT_CODE': 701}]},
#   'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'At Central Ave - Roadwork.',
#     'TYPE': 'short_desc'},
#    {'value': 'At Central Ave - Roadwork. - expect intermittent lane closures at various intervals',
#     'TYPE': 'desc'},
#    {'value': 'Roadwork. - expect intermittent lane closures at various intervals',
#     'TYPE': 'no_exit_description'}],
#   'mid': 'HERE-Non-Europe-PR/r_HERE-Non-Europe-PR/591144_TIC/NAVTEQ_reverse|1582317199029',
#   'PRODUCT': 'basic'},
#  {'TRAFFIC_ITEM_ID': 1749675332392041807,
#   'ORIGINAL_TRAFFIC_ITEM_ID': 772102148842877395,
#   'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#   'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#   'START_TIME': '02/21/2020 21:32:26',
#   'END_TIME': '02/22/2020 02:31:48',
#   'ENTRY_TIME': '02/21/2020 21:32:26',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#      'STREET1': {'ADDRESS1': '2nd Pl'},
#      'STREET2': {'ADDRESS1': 'W 2nd St'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}},
#     'TO': {'ID': '',
#      'STREET1': {'ADDRESS1': '2nd Pl'},
#      'STREET2': {'ADDRESS1': 'S Hope St'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.054636, 'LONGITUDE': -118.251462},
#     'TO': [{'LATITUDE': 34.054907, 'LONGITUDE': -118.251555}],
#     'GEOMETRY': {'SHAPES': {'SHP': [{'value': '34.05454,-118.25143 34.0551,-118.25162',
#         'FC': 5,
#         'LID': '121238091F',
#         'LE': 0.06454654204008707,
#         'FW': 'SD'}]}}},
#    'POLITICAL_BOUNDARY': {'METRO_AREA': {'value': '', 'ID': 6},
#     'COUNTY': 'Los Angeles'},
#    'NAVTECH': {'EDGE': {'EDGE_ID': ['121238091']}, 'VERSION_ID': '202001'},
#    'LENGTH': 0.0401},
#   'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#    'EVENT': {'EVENT_ITEM_CANCELLED': False,
#     'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#      'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#    'ALERTC': [{'EVENT_CODE': 735}]},
#   'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed between W 2nd St and S Hope St - Closed due to roadwork.',
#     'TYPE': 'short_desc'},
#    {'value': 'Closed between W 2nd St and S Hope St - Closed due to roadwork.',
#     'TYPE': 'desc'},
#    {'value': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}],
#   'mid': 'HERE-Non-Europe-PR/r_HERE-Non-Europe-PR/233277_TIC/NAVTEQ_original|1582320735075',
#   'PRODUCT': 'basic'},
#  {'TRAFFIC_ITEM_ID': 567231854065805544,
#   'ORIGINAL_TRAFFIC_ITEM_ID': 1494058245138308526,
#   'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#   'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#   'START_TIME': '02/21/2020 20:33:54',
#   'END_TIME': '02/25/2020 20:31:48',
#   'ENTRY_TIME': '02/21/2020 20:33:54',
#   'CRITICALITY': {'ID': '2', 'DESCRIPTION': 'minor'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'COMMENTS': '. Expect intermittent lane closures at various intervals - fiber optics project through March 2020',
#   'RDS-TMC_LOCATIONS': {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '09744',
#       'LOCATION_DESC': 'Livingston Dr',
#       'RDS_DIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFIC_CODE': 701,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Roadwork.',
#       'ALERTC_DURATION': 'L',
#       'ALERTC_DIRECTION': 1,
#       'UPDATE_CLASS': 11,
#       'PHRASE_CODE': 'E1',
#       'EXTENT': '1',
#       'DURATION': 0},
#      'LENGTH': 1.20578,
#      'PRIMARY_OFFSET': 0.0}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'value': '2nd St',
#         'TYPE': 'NTCSA'},
#        {'value': '2nd St', 'TYPE': 'RDSGN'},
#        {'value': '2nd St', 'TYPE': 'LOCAL'}],
#       'ID': 752},
#      'POINT': {'DESCRIPTION': [{'value': 'Naples Plz', 'TYPE': 'NTCSA'},
#        {'value': 'Naples Plz', 'TYPE': 'RDSGN'},
#        {'value': 'Naples Plz', 'TYPE': 'LOCAL'},
#        {'value': '2nd St', 'TYPE': 'BNAME'}],
#       'ID': 9744},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'WESTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'WESTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'WESTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'value': '2nd St', 'TYPE': 'NTCSA'},
#        {'value': '2nd St', 'TYPE': 'RDSGN'},
#        {'value': '2nd St', 'TYPE': 'LOCAL'}],
#       'ID': 752},
#      'POINT': {'DESCRIPTION': [{'value': 'Livingston Dr', 'TYPE': 'NTCSA'},
#        {'value': 'Livingston Dr', 'TYPE': 'RDSGN'},
#        {'value': 'Livingston Dr', 'TYPE': 'LOCAL'},
#        {'value': '2nd St', 'TYPE': 'BNAME'}],
#       'ID': 9744},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'WESTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'WESTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'WESTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 33.75643, 'LONGITUDE': -118.12013},
#     'TO': [{'LATITUDE': 33.76231, 'LONGITUDE': -118.13963}]},
#    'NAVTECH': {'EDGE': {'EDGE_ID': ['126537403',
#       '943807750',
#       '943807751',
#       '1149936747',
#       '1149936871',
#       '1149936872',
#       '1149937299',
#       '1149937300',
#       '1066601301',
#       '1066601302',
#       '1066601313',
#       '1149938201',
#       '1149938202',
#       '23892520',
#       '24585219',
#       '1149938939',
#       '1149938940',
#       '23882728',
#       '1149939581',
#       '1149939582',
#       '1149939826',
#       '1149939827',
#       '999608389',
#       '1150052064',
#       '1150052648',
#       '1150052649',
#       '1252445510',
#       '1252445511',
#       '23882558',
#       '23882557',
#       '23882556',
#       '23882555',
#       '23882554',
#       '23882553',
#       '23882552',
#       '23882551',
#       '23882547',
#       '23882544',
#       '763065033',
#       '763065034',
#       '23882540',
#       '1150049674',
#       '1150049675',
#       '126537389']},
#     'VERSION_ID': '202001'},
#    'LENGTH': 1.20578},
#   'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': False,
#    'EVENT': {'EVENT_ITEM_CANCELLED': False,
#     'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#      'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#    'ALERTC': [{'EVENT_CODE': 701}]},
#   'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'At Livingston Dr - Roadwork.',
#     'TYPE': 'short_desc'},
#    {'value': 'At Livingston Dr - Roadwork. . Expect intermittent lane closures at various intervals - fiber optics project through March 2020',
#     'TYPE': 'desc'},
#    {'value': 'Roadwork. . Expect intermittent lane closures at various intervals - fiber optics project through March 2020',
#     'TYPE': 'no_exit_description'}],
#   'mid': 'HERE-Non-Europe-PR/r_HERE-Non-Europe-PR/715574_TIC/NAVTEQ_reverse|1582317199028',
#   'PRODUCT': 'basic'},
#  {'TRAFFIC_ITEM_ID': 916221091233092267,
#   'ORIGINAL_TRAFFIC_ITEM_ID': 916221091233092267,
#   'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#   'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#   'START_TIME': '02/21/2020 16:54:50',
#   'END_TIME': '02/25/2020 16:54:32',
#   'ENTRY_TIME': '02/21/2020 16:54:50',
#   'CRITICALITY': {'ID': '1', 'DESCRIPTION': 'major'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'COMMENTS': '- daily 9am - 3:30pm expect intermittent lane closures due to the SoCal Gas Pipeline Project, scheduled thru June 2020',
#   'RDS-TMC_LOCATIONS': {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '16389',
#       'LOCATION_DESC': 'Sierra Bonita Ave',
#       'RDS_DIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFIC_CODE': 701,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Roadwork.',
#       'ALERTC_DURATION': 'L',
#       'ALERTC_DIRECTION': 1,
#       'UPDATE_CLASS': 11,
#       'PHRASE_CODE': 'E1',
#       'EXTENT': '1',
#       'DURATION': 0},
#      'LENGTH': 0.26664,
#      'PRIMARY_OFFSET': 0.1446}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'value': 'Pico Blvd',
#         'TYPE': 'NTCSA'},
#        {'value': 'Pico Blvd', 'TYPE': 'RDSGN'},
#        {'value': 'Pico Blvd', 'TYPE': 'LOCAL'}],
#       'ID': 1910},
#      'POINT': {'DESCRIPTION': [{'value': 'Genesee Ave', 'TYPE': 'NTCSA'},
#        {'value': 'Genesee Ave', 'TYPE': 'RDSGN'},
#        {'value': 'Genesee Ave', 'TYPE': 'LOCAL'},
#        {'value': 'Pico Blvd', 'TYPE': 'BNAME'}],
#       'ID': 16389},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'EASTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'EASTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'EASTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'value': 'Pico Blvd', 'TYPE': 'NTCSA'},
#        {'value': 'Pico Blvd', 'TYPE': 'RDSGN'},
#        {'value': 'Pico Blvd', 'TYPE': 'LOCAL'}],
#       'ID': 1910},
#      'POINT': {'DESCRIPTION': [{'value': 'Sierra Bonita Ave', 'TYPE': 'NTCSA'},
#        {'value': 'Sierra Bonita Ave', 'TYPE': 'RDSGN'},
#        {'value': 'Sierra Bonita Ave', 'TYPE': 'LOCAL'},
#        {'value': 'Pico Blvd', 'TYPE': 'BNAME'}],
#       'ID': 16389},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'EASTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'EASTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'EASTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.05092, 'LONGITUDE': -118.3635},
#     'TO': [{'LATITUDE': 34.04952, 'LONGITUDE': -118.35919}]},
#    'NAVTECH': {'EDGE': {'EDGE_ID': ['23920193',
#       '1151662522',
#       '1151662521',
#       '23920195',
#       '1253791990',
#       '1253791989',
#       '23920197',
#       '23920198',
#       '23920199',
#       '23920200',
#       '1151635452',
#       '1151635451']},
#     'VERSION_ID': '202001'},
#    'LENGTH': 0.26664},
#   'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': False,
#    'EVENT': {'EVENT_ITEM_CANCELLED': False,
#     'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#      'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#    'ALERTC': [{'EVENT_CODE': 701}]},
#   'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'At Sierra Bonita Ave - Roadwork.',
#     'TYPE': 'short_desc'},
#    {'value': 'At Sierra Bonita Ave - Roadwork. - daily 9am - 3:30pm expect intermittent lane closures due to the SoCal Gas Pipeline Project, scheduled thru June 2020',
#     'TYPE': 'desc'},
#    {'value': 'Roadwork. - daily 9am - 3:30pm expect intermittent lane closures due to the SoCal Gas Pipeline Project, scheduled thru June 2020',
#     'TYPE': 'no_exit_description'}],
#   'mid': 'HERE-Non-Europe-PR/r_HERE-Non-Europe-PR/706349_TIC/NAVTEQ_original|1582304072283',
#   'PRODUCT': 'basic'},
#  {'TRAFFIC_ITEM_ID': 4065917199335336274,
#   'ORIGINAL_TRAFFIC_ITEM_ID': 2449879648462055056,
#   'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#   'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#   'START_TIME': '02/21/2020 21:32:26',
#   'END_TIME': '02/22/2020 02:31:48',
#   'ENTRY_TIME': '02/21/2020 21:32:26',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'RDS-TMC_LOCATIONS': {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '07333',
#       'LOCATION_DESC': 'CA-39/N San Gabriel Canyon Rd',
#       'RDS_DIRECTION': '-'},
#      'TO': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '07335',
#       'LOCATION_DESC': 'Big Pines Hwy',
#       'RDS_DIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFIC_CODE': 735,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Closed due to roadwork.',
#       'ALERTC_DURATION': 'L',
#       'ALERTC_DIRECTION': 1,
#       'URGENCY': 'U',
#       'UPDATE_CLASS': 5,
#       'PHRASE_CODE': 'E1.C1',
#       'EXTENT': '3',
#       'DURATION': 0},
#      'LENGTH': 15.43488,
#      'PRIMARY_OFFSET': 0.30041},
#     {'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '07333',
#       'LOCATION_DESC': 'CA-39/N San Gabriel Canyon Rd',
#       'RDS_DIRECTION': '-'},
#      'TO': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '07335',
#       'LOCATION_DESC': 'Big Pines Hwy',
#       'RDS_DIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFIC_CODE': 214,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Incident.',
#       'ALERTC_DURATION': '(D)',
#       'ALERTC_DIRECTION': 1,
#       'UPDATE_CLASS': 4,
#       'PHRASE_CODE': 'B14',
#       'EXTENT': '3',
#       'DURATION': 0},
#      'LENGTH': 15.43488,
#      'PRIMARY_OFFSET': 0.30041}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'value': 'Angeles Crest Hwy',
#         'TYPE': 'NTCSA'},
#        {'value': 'Angeles Crest Hwy', 'TYPE': 'RDSGN'},
#        {'value': 'Angeles Crest Hwy', 'TYPE': 'LOCAL'}],
#       'ID': 528},
#      'POINT': {'DESCRIPTION': [{'value': 'CA-39/N San Gabriel Canyon Rd',
#         'TYPE': 'NTCSA'},
#        {'value': 'CA-39/N San Gabriel Canyon Rd', 'TYPE': 'RDSGN'},
#        {'value': 'CA-39/N San Gabriel Canyon Rd', 'TYPE': 'LOCAL'},
#        {'value': 'Angeles Crest Hwy', 'TYPE': 'BNAME'}],
#       'ID': 7333},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'NORTHBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'NORTHBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'NORTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'value': 'Angeles Crest Hwy',
#         'TYPE': 'NTCSA'},
#        {'value': 'Angeles Crest Hwy', 'TYPE': 'RDSGN'},
#        {'value': 'Angeles Crest Hwy', 'TYPE': 'LOCAL'}],
#       'ID': 528},
#      'POINT': {'DESCRIPTION': [{'value': 'Big Pines Hwy', 'TYPE': 'NTCSA'},
#        {'value': 'Big Pines Hwy', 'TYPE': 'RDSGN'},
#        {'value': 'Big Pines Hwy', 'TYPE': 'LOCAL'},
#        {'value': 'Angeles Crest Hwy', 'TYPE': 'BNAME'}],
#       'ID': 7335},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'NORTHBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'NORTHBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'NORTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.35703, 'LONGITUDE': -117.85057},
#     'TO': [{'LATITUDE': 34.37833, 'LONGITUDE': -117.69574}]},
#    'NAVTECH': {'EDGE': {'EDGE_ID': ['1041050573',
#       '1041050572',
#       '775766853',
#       '775766852',
#       '1150105471',
#       '1150105472',
#       '1150092864',
#       '1150092865',
#       '1131201612',
#       '1150092862',
#       '1150092863',
#       '23976715',
#       '23976803',
#       '776743738',
#       '776743739',
#       '128820764',
#       '128820765']},
#     'VERSION_ID': '202001'},
#    'LENGTH': 15.43488},
#   'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#    'EVENT': {'EVENT_ITEM_CANCELLED': False,
#     'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#      'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#    'ALERTC': [{'EVENT_CODE': 735}, {'EVENT_CODE': 214}]},
#   'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed between CA-39/N San Gabriel Canyon Rd and Big Pines Hwy - Closed due to roadwork. Incident.',
#     'TYPE': 'short_desc'},
#    {'value': 'Closed between CA-39/N San Gabriel Canyon Rd and Big Pines Hwy - Closed due to roadwork. Incident.',
#     'TYPE': 'desc'},
#    {'value': 'Closed due to roadwork. Incident.',
#     'TYPE': 'no_exit_description'}],
#   'mid': '1fa3bb0c-4094-4cd6-a856-e205e83318f6|1582320746173',
#   'PRODUCT': 'basic'},
#  {'TRAFFIC_ITEM_ID': 2620509109630442748,
#   'ORIGINAL_TRAFFIC_ITEM_ID': 599856952568915634,
#   'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#   'TRAFFIC_ITEM_TYPE_DESC': 'ROAD_CLOSURE',
#   'START_TIME': '02/21/2020 21:32:26',
#   'END_TIME': '02/22/2020 02:31:48',
#   'ENTRY_TIME': '02/21/2020 21:32:26',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
# ...
#      'POINT': {'DESCRIPTION': [{'value': 'S Chicago St/I-10/I-5',
#         'TYPE': 'NTCSA'},
#        {'value': 'S Chicago St/I-10/I-5', 'TYPE': 'RDSGN'},
#        {'value': 'S Chicago St/I-10/I-5', 'TYPE': 'LOCAL'},
#        {'value': 'E 6th St/Whittier Blvd', 'TYPE': 'BNAME'}],
#       'ID': 6982},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'SOUTHBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'SOUTHBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'SOUTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.03853, 'LONGITUDE': -118.22796},
#     'TO': [{'LATITUDE': 34.03567, 'LONGITUDE': -118.21871}]},
#    'NAVTECH': {'EDGE': {'EDGE_ID': ['1034454511',
#       '1034454510',
#       '909234972',
#       '909234971',
#       '782857551',
#       '782857550',
#       '764258587',
#       '764258586',
#       '764258589',
#       '782857549',
#       '782857548',
#       '23908123']},
#     'VERSION_ID': '202001'},
#    'LENGTH': 0.56816},
#   'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#    'EVENT': {'EVENT_ITEM_CANCELLED': False,
#     'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#      'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#    'ALERTC': [{'EVENT_CODE': 735}]},
#   'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed between E 6th St and S Chicago St/I-10/I-5 - Closed due to roadwork.',
#     'TYPE': 'short_desc'},
#    {'value': 'Closed between E 6th St and S Chicago St/I-10/I-5 - Closed due to roadwork. . Project scheduled thru early 2022',
#     'TYPE': 'desc'},
#    {'value': 'Closed due to roadwork. . Project scheduled thru early 2022',
#     'TYPE': 'no_exit_description'}],
#   'mid': 'HERE-Non-Europe-PR/r_HERE-Non-Europe-PR/582922_TIC/NAVTEQ-1_reverse|1582317199028',
#   'PRODUCT': 'basic'},
#  {'TRAFFIC_ITEM_ID': 781708797613707128,
#   'ORIGINAL_TRAFFIC_ITEM_ID': 1368223386960921215,
#   'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#   'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#   'START_TIME': '02/21/2020 20:33:54',
#   'END_TIME': '02/25/2020 20:31:48',
#   'ENTRY_TIME': '02/21/2020 20:33:54',
#   'CRITICALITY': {'ID': '2', 'DESCRIPTION': 'minor'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'COMMENTS': '- project scheduled thru Summer 2020',
#   'RDS-TMC_LOCATIONS': {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '16644',
#       'LOCATION_DESC': 'San Vicente Blvd/Vineyard Ave',
#       'RDS_DIRECTION': '-'},
#      'TO': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '16645',
#       'LOCATION_DESC': 'S Normandie Ave',
#       'RDS_DIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFIC_CODE': 803,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Construction work.',
#       'ALERTC_DURATION': 'L',
#       'ALERTC_DIRECTION': 1,
#       'UPDATE_CLASS': 11,
#       'PHRASE_CODE': 'E11',
#       'EXTENT': '2',
#       'DURATION': 0},
#      'LENGTH': 0.34445,
#      'PRIMARY_OFFSET': 0.21165}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'value': 'Venice Blvd',
#         'TYPE': 'NTCSA'},
#        {'value': 'Venice Blvd', 'TYPE': 'RDSGN'},
#        {'value': 'Venice Blvd', 'TYPE': 'LOCAL'}],
#       'ID': 415},
#      'POINT': {'DESCRIPTION': [{'value': 'San Vicente Blvd/Vineyard Ave',
#         'TYPE': 'NTCSA'},
#        {'value': 'San Vicente Blvd/Vineyard Ave', 'TYPE': 'RDSGN'},
#        {'value': 'San Vicente Blvd/Vineyard Ave', 'TYPE': 'LOCAL'},
#        {'value': 'Venice Blvd', 'TYPE': 'BNAME'}],
#       'ID': 16644},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'EASTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'EASTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'EASTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'value': 'Venice Blvd',
#         'TYPE': 'NTCSA'},
#        {'value': 'Venice Blvd', 'TYPE': 'RDSGN'},
#        {'value': 'Venice Blvd', 'TYPE': 'LOCAL'}],
#       'ID': 415},
#      'POINT': {'DESCRIPTION': [{'value': 'S Normandie Ave', 'TYPE': 'NTCSA'},
#        {'value': 'S Normandie Ave', 'TYPE': 'RDSGN'},
#        {'value': 'S Normandie Ave', 'TYPE': 'LOCAL'},
#        {'value': 'Venice Blvd', 'TYPE': 'BNAME'}],
#       'ID': 16645},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'EASTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'EASTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'EASTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.04356, 'LONGITUDE': -118.31011},
#     'TO': [{'LATITUDE': 34.04361, 'LONGITUDE': -118.30414}]},
#    'NAVTECH': {'EDGE': {'EDGE_ID': ['996980623',
#       '996980624',
#       '763778991',
#       '763778992',
#       '763778993',
#       '23842024',
#       '23842026',
#       '23842027',
#       '23842029']},
#     'VERSION_ID': '202001'},
#    'LENGTH': 0.34445},
#   'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': False,
#    'EVENT': {'EVENT_ITEM_CANCELLED': False,
#     'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#      'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#    'ALERTC': [{'EVENT_CODE': 803}]},
#   'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Between San Vicente Blvd/Vineyard Ave and S Normandie Ave - Construction work.',
#     'TYPE': 'short_desc'},
#    {'value': 'Between San Vicente Blvd/Vineyard Ave and S Normandie Ave - Construction work. - project scheduled thru Summer 2020',
#     'TYPE': 'desc'},
#    {'value': 'Construction work. - project scheduled thru Summer 2020',
#     'TYPE': 'no_exit_description'}],
#   'mid': 'HERE-Non-Europe-PR/r_HERE-Non-Europe-PR/596527_TIC/NAVTEQ_reverse|1582317199028',
#   'PRODUCT': 'basic'},
#  {'TRAFFIC_ITEM_ID': 3181474143153090142,
#   'ORIGINAL_TRAFFIC_ITEM_ID': 3264380376329347204,
#   'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#   'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#   'START_TIME': '02/21/2020 21:32:26',
#   'END_TIME': '02/22/2020 02:31:48',
#   'ENTRY_TIME': '02/21/2020 21:32:26',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'RDS-TMC_LOCATIONS': {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '26322',
#       'LOCATION_DESC': 'I-405/Westminster Blvd',
#       'RDS_DIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFIC_CODE': 735,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Closed due to roadwork.',
#       'ALERTC_DURATION': 'L',
#       'ALERTC_DIRECTION': 1,
#       'URGENCY': 'U',
#       'UPDATE_CLASS': 5,
#       'PHRASE_CODE': 'E1.C1',
#       'EXTENT': '0',
#       'DURATION': 0},
#      'LENGTH': 0.19573,
#      'PRIMARY_OFFSET': 0.0}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'value': 'San Diego Fwy',
#         'TYPE': 'NTCSA'},
#        {'value': 'San Diego Fwy', 'TYPE': 'RDSGN'},
#        {'value': 'San Diego Fwy', 'TYPE': 'LOCAL'}],
#       'ID': 26321},
#      'POINT': {'DESCRIPTION': [{'value': 'I-405/Westminster Blvd',
#         'TYPE': 'NTCSA'},
#        {'value': 'I-405/Westminster Blvd', 'TYPE': 'RDSGN'},
#        {'value': 'I-405/Westminster Blvd', 'TYPE': 'LOCAL'},
#        {'value': 'San Diego Fwy', 'TYPE': 'BNAME'}],
#       'ID': 26322},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'SPRINGDALE ST', 'TYPE': 'LOCAL'},
#        {'value': 'SPRINGDALE ST', 'TYPE': 'NTCSA'},
#        {'value': 'SPRINGDALE ST', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'RMP',
#       'DESCRIPTION': 'ramp(freeway connector or defined off-ramp)'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'value': 'San Diego Fwy',
#         'TYPE': 'NTCSA'},
#        {'value': 'San Diego Fwy', 'TYPE': 'RDSGN'},
#        {'value': 'San Diego Fwy', 'TYPE': 'LOCAL'}],
#       'ID': 26321},
#      'POINT': {'DESCRIPTION': [{'value': 'I-405/Westminster Blvd',
#         'TYPE': 'NTCSA'},
#        {'value': 'I-405/Westminster Blvd', 'TYPE': 'RDSGN'},
#        {'value': 'I-405/Westminster Blvd', 'TYPE': 'LOCAL'},
#        {'value': 'San Diego Fwy', 'TYPE': 'BNAME'}],
#       'ID': 26322},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'SPRINGDALE ST', 'TYPE': 'LOCAL'},
#        {'value': 'SPRINGDALE ST', 'TYPE': 'NTCSA'},
#        {'value': 'SPRINGDALE ST', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'RMP',
#       'DESCRIPTION': 'ramp(freeway connector or defined off-ramp)'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 33.76209, 'LONGITUDE': -118.02611},
#     'TO': [{'LATITUDE': 33.75981, 'LONGITUDE': -118.02464}]},
#    'NAVTECH': {'EDGE': {'EDGE_ID': ['1002317914',
#       '1002317913',
#       '1129625450',
#       '1129625449',
#       '1036358602']},
#     'VERSION_ID': '202001'},
#    'LENGTH': 0.19573},
#   'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#    'EVENT': {'EVENT_ITEM_CANCELLED': False,
#     'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#      'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#    'ALERTC': [{'EVENT_CODE': 735}]},
#   'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Ramp  closed to I-405/Westminster Blvd - Closed due to roadwork.',
#     'TYPE': 'short_desc'},
#    {'value': 'Ramp  closed to I-405/Westminster Blvd - Closed due to roadwork.',
#     'TYPE': 'desc'},
#    {'value': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}],
#   'mid': 'HERE-Non-Europe-PR/r_HERE-Non-Europe-PR/708240_TIC/NAVTEQ|1582320735076',
#   'PRODUCT': 'basic'},
#  {'TRAFFIC_ITEM_ID': 440509231014335517,
#   'ORIGINAL_TRAFFIC_ITEM_ID': 2533150597608165322,
#   'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#   'TRAFFIC_ITEM_TYPE_DESC': 'ROAD_CLOSURE',
#   'START_TIME': '02/21/2020 21:32:26',
#   'END_TIME': '02/22/2020 02:31:48',
#   'ENTRY_TIME': '02/21/2020 21:32:26',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORT_DESC': 'CLOS', 'DESCRIPTION': ''},
#   'RDS-TMC_LOCATIONS': {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '05743',
#       'LOCATION_DESC': 'Holt Ave',
#       'RDS_DIRECTION': '+'},
#      'DIRECTION': '-',
#      'ALERTC': {'TRAFFIC_CODE': 407,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Exit ramp closed.',
#       'ALERTC_DURATION': 'L',
#       'ALERTC_DIRECTION': 1,
#       'URGENCY': 'U',
#       'UPDATE_CLASS': 7,
#       'PHRASE_CODE': 'C7',
#       'EXTENT': '0',
#       'DURATION': 0},
#      'LENGTH': 0.0,
#      'PRIMARY_OFFSET': 0.39657}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'value': 'San Bernardino Fwy',
#         'TYPE': 'NTCSA'},
#        {'value': 'San Bernardino Fwy', 'TYPE': 'RDSGN'},
#        {'value': 'San Bernardino Fwy', 'TYPE': 'LOCAL'}],
#       'ID': 91},
#      'POINT': {'DESCRIPTION': [{'value': 'Holt Ave', 'TYPE': 'NTCSA'},
#        {'value': 'Holt Ave', 'TYPE': 'RDSGN'},
#        {'value': 'Holt Ave', 'TYPE': 'LOCAL'},
#        {'value': 'San Bernardino Fwy', 'TYPE': 'BNAME'}],
#       'ID': 5743},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'EASTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'EASTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'EASTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'value': 'San Bernardino Fwy',
#         'TYPE': 'NTCSA'},
#        {'value': 'San Bernardino Fwy', 'TYPE': 'RDSGN'},
#        {'value': 'San Bernardino Fwy', 'TYPE': 'LOCAL'}],
#       'ID': 91},
#      'POINT': {'DESCRIPTION': [{'value': 'Holt Ave', 'TYPE': 'NTCSA'},
#        {'value': 'Holt Ave', 'TYPE': 'RDSGN'},
#        {'value': 'Holt Ave', 'TYPE': 'LOCAL'},
#        {'value': 'San Bernardino Fwy', 'TYPE': 'BNAME'}],
#       'ID': 5743},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'EASTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'EASTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'EASTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.07145, 'LONGITUDE': -117.86819},
#     'TO': [{'LATITUDE': 34.07145, 'LONGITUDE': -117.86819}]},
#    'NAVTECH': {'EDGE': {'EDGE_ID': ['24041372']}, 'VERSION_ID': '202001'},
#    'LENGTH': 0.0},
#   'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': False,
#    'INCIDENT': {'RESPONSE_VEHICLES': False,
#     'MISCELLANEOUS_INCIDENT': {'MISCELLANEOUS_TYPE_DESC': ''}},
#    'ALERTC': [{'EVENT_CODE': 407}]},
#   'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'At Holt Ave - Exit ramp closed.',
#     'TYPE': 'short_desc'},
#    {'value': 'At Holt Ave - Exit ramp closed.', 'TYPE': 'desc'},
#    {'value': 'Exit ramp closed.', 'TYPE': 'no_exit_description'}],
#   'mid': 'HERE-Non-Europe-PR/r_HERE-Non-Europe-PR/715539_TIC/NAVTEQ|1582320735076',
#   'PRODUCT': 'basic'},
#  {'TRAFFIC_ITEM_ID': 2780657142140422342,
#   'ORIGINAL_TRAFFIC_ITEM_ID': 1289195304702242863,
#   'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#   'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#   'START_TIME': '02/21/2020 20:33:54',
#   'END_TIME': '02/25/2020 20:31:48',
#   'ENTRY_TIME': '02/21/2020 20:33:54',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'RDS-TMC_LOCATIONS': {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#       'TABLE_ID': 6,
#       'LOCATION_ID': '09741',
#       'LOCATION_DESC': 'Long Beach Fwy',
#       'RDS_DIRECTION': '+'},
#      'DIRECTION': '-',
#      'ALERTC': {'TRAFFIC_CODE': 735,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Closed due to roadwork.',
#       'ALERTC_DURATION': 'L',
#       'ALERTC_DIRECTION': 1,
#       'URGENCY': 'U',
#       'UPDATE_CLASS': 5,
#       'PHRASE_CODE': 'E1.C1',
#       'EXTENT': '1',
#       'DURATION': 0},
#      'LENGTH': 0.36845,
#      'PRIMARY_OFFSET': 0.04288}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'value': 'Ocean Blvd',
#         'TYPE': 'NTCSA'},
#        {'value': 'Ocean Blvd', 'TYPE': 'RDSGN'},
#        {'value': 'Ocean Blvd', 'TYPE': 'LOCAL'}],
#       'ID': 751},
#      'POINT': {'DESCRIPTION': [{'value': 'Long Beach Fwy', 'TYPE': 'NTCSA'},
#        {'value': 'Long Beach Fwy', 'TYPE': 'RDSGN'},
#        {'value': 'Long Beach Fwy', 'TYPE': 'LOCAL'},
#        {'value': 'Ocean Blvd', 'TYPE': 'BNAME'}],
#       'ID': 9741},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'EASTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'EASTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'EASTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'value': 'Ocean Blvd',
#         'TYPE': 'NTCSA'},
#        {'value': 'Ocean Blvd', 'TYPE': 'RDSGN'},
#        {'value': 'Ocean Blvd', 'TYPE': 'LOCAL'}],
#       'ID': 751},
#      'POINT': {'DESCRIPTION': [{'value': 'Long Beach Fwy', 'TYPE': 'NTCSA'},
#        {'value': 'Long Beach Fwy', 'TYPE': 'RDSGN'},
#        {'value': 'Long Beach Fwy', 'TYPE': 'LOCAL'},
#        {'value': 'Ocean Blvd', 'TYPE': 'BNAME'}],
#       'ID': 9741},
#      'DIRECTION': {'DESCRIPTION': [{'value': 'EASTBOUND', 'TYPE': 'LOCAL'},
#        {'value': 'EASTBOUND', 'TYPE': 'NTCSA'},
#        {'value': 'EASTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 33.7667, 'LONGITUDE': -118.2118},
#     'TO': [{'LATITUDE': 33.76724, 'LONGITUDE': -118.20545}]},
#    'NAVTECH': {'EDGE': {'EDGE_ID': ['1150065234',
#       '1150065235',
#       '778344343',
#       '955248425',
#       '1150063551',
#       '1150063552']},
#     'VERSION_ID': '202001'},
#    'LENGTH': 0.36845},
#   'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#    'EVENT': {'EVENT_ITEM_CANCELLED': False,
#     'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#      'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#    'ALERTC': [{'EVENT_CODE': 735}]},
#   'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at Long Beach Fwy - Closed due to roadwork.',
#     'TYPE': 'short_desc'},
#    {'value': 'Closed at Long Beach Fwy - Closed due to roadwork.',
#     'TYPE': 'desc'},
#    {'value': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}],
#   'mid': 'HERE-Non-Europe-PR/r_HERE-Non-Europe-PR/602111_TIC/NAVTEQ_reverse|1582317199028',
#   'PRODUCT': 'basic'}]

# %% [markdown]
# ## Extract necessary data from the dictionaries

# %% [markdown]
# **Create a DataFrame of the dictionaries**

# %%
here_incidents = pd.DataFrame(inc_dict)

# %% [markdown]
# **Check how many incidents were found.  In this case there are 306.**

# %%
here_incidents.shape
# Out:
# (315, 17)

# %% [markdown]
# **Inspect the columns to find which column has the geolocation info we are looking for.**

# %%
here_incidents.columns
# Out:
# Index(['TRAFFIC_ITEM_ID', 'ORIGINAL_TRAFFIC_ITEM_ID',
#        'TRAFFIC_ITEM_STATUS_SHORT_DESC', 'TRAFFIC_ITEM_TYPE_DESC',
#        'START_TIME', 'END_TIME', 'ENTRY_TIME', 'CRITICALITY', 'VERIFIED',
#        'ABBREVIATION', 'RDS-TMC_LOCATIONS', 'LOCATION', 'TRAFFIC_ITEM_DETAIL',
#        'TRAFFIC_ITEM_DESCRIPTION', 'mid', 'PRODUCT', 'COMMENTS'],
#       dtype='object')

# %% [markdown]
# **'LOCATION' looks like what we are looking for.  Turn 'LOCATION' into a DataFrame and then inspect:**

# %%
locations = pd.DataFrame(list(here_incidents['LOCATION']))
locations.head()
# Out:
#                                              DEFINED  \
# 0  {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'valu...
# 1  {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'valu...
# 2  {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'valu...
# 3                                                NaN
# 4  {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'valu...
#
#                                               GEOLOC  \
# 0  {'ORIGIN': {'LATITUDE': 34.04039, 'LONGITUDE':...
# 1  {'ORIGIN': {'LATITUDE': 34.05102, 'LONGITUDE':...
# 2  {'ORIGIN': {'LATITUDE': 34.05776, 'LONGITUDE':...
# 3  {'ORIGIN': {'LATITUDE': 33.75693, 'LONGITUDE':...
# 4  {'ORIGIN': {'LATITUDE': 34.02935, 'LONGITUDE':...
#
#                                              NAVTECH   LENGTH  \
# 0  {'EDGE': {'EDGE_ID': ['1146410624', '114641062...  2.53938
# 1  {'EDGE': {'EDGE_ID': ['1152678298', '115273328...  0.73867
# 2  {'EDGE': {'EDGE_ID': ['764603554', '764603555'...  0.84830
# 3  {'EDGE': {'EDGE_ID': ['121238382', '1195443886...  0.12457
# 4  {'EDGE': {'EDGE_ID': ['1183421426', '118342142...  0.45780
#
#                                         INTERSECTION  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  {'ORIGIN': {'ID': '', 'STREET1': {'ADDRESS1': ...
# 4                                                NaN
#
#                                   POLITICAL_BOUNDARY
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  {'METRO_AREA': {'value': '', 'ID': 6}, 'COUNTY...
# 4                                                NaN

# %% [markdown]
# **Double checking to make sure we still have all 306 incidents:**

# %%
locations.shape
# Out:
# (315, 6)

# %% [markdown]
# **'GEOLOC' is a nested dictionary that looks like it has exactly what we are looking for - the Latitude and Longitude of the 'incident'.  We will turn that into a DataFrame and inspect:**

# %%
geo_cords = pd.DataFrame(list(locations['GEOLOC']))
geo_cords.head()
# Out:
#                                             ORIGIN  \
# 0  {'LATITUDE': 34.04039, 'LONGITUDE': -118.88558}
# 1  {'LATITUDE': 34.05102, 'LONGITUDE': -118.24453}
# 2  {'LATITUDE': 34.05776, 'LONGITUDE': -118.44775}
# 3  {'LATITUDE': 33.75693, 'LONGITUDE': -118.12304}
# 4  {'LATITUDE': 34.02935, 'LONGITUDE': -118.20087}
#
#                                                   TO  \
# 0  [{'LATITUDE': 34.03112, 'LONGITUDE': -118.84363}]
# 1   [{'LATITUDE': 34.05944, 'LONGITUDE': -118.2368}]
# 2  [{'LATITUDE': 34.06151, 'LONGITUDE': -118.43369}]
# 3  [{'LATITUDE': 33.75516, 'LONGITUDE': -118.12345}]
# 4  [{'LATITUDE': 34.02847, 'LONGITUDE': -118.20875}]
#
#                                             GEOMETRY
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  {'SHAPES': {'SHP': [{'value': '33.75693,-118.1...
# 4                                                NaN

# %% [markdown]
# **'ORIGIN' column has dictionary entries of Latitude and Longitude as key:value pairs so now split them into their own columns so we are left with 2 columns - 'Latitude' and 'Longitude' that we can then plot on a map:**

# %%
origin_cords = geo_cords['ORIGIN'].apply(pd.Series).rename(columns={'LATITUDE': 'Latitude', 'LONGITUDE': 'Longitude'})
origin_cords.head()
# Out:
#    Latitude  Longitude
# 0  34.07228 -118.08451
# 1  34.03853 -118.22796
# 2  34.27184 -118.47214
# 3  34.04039 -118.88558
# 4  34.06066 -118.24938

# %% [markdown]
# **One final check to make sure we have all 306 incidents...**

# %%
origin_cords.shape
# Out:
# (306, 2)

# %% [markdown]
# **Save Latitude and Longitude data in a .csv file:**

# %%
# Save to a csv
origin_cords.to_csv('here_incidents_FINAL.csv')

# %% [markdown]
# **DONE!**
